# %%
### Name - Shubham Raut
### PRN - 250840325067
### email - shubhamraut.cdac.mum.aug25@gmail.com

# %%
class Account:
  Account_no=1000

  def __init__(self,name,balance,gender):
    # print(f"New account Created {id(self)}")
    #self.__account_number=1001
    Account.Account_no+=1
    self.__name=name
    self.__balance=balance
    self.__gender=gender
    if self.__balance>=3000:
      print("Account created")
    else:
      print("Required min balance is 3000 or above")
    print(f"Account number:{Account.Account_no}")

    print(f"Account created with accno:{Account.Account_no}")
  #def (self,acc_number,initial_):
  def deposit(self,acc_number):
    if acc_number in s:
      amount=float(input("enter amount: "))
      if amount>0:
        self.__amount=amount
        self.__balance=self.__balance+self.__amount
        return f"n balance={self.__balance}"
      else :
        return "deposit cant be negative"


  def withdraw(self,acc_number):
    if acc_number in s:
      amount=int(input("enter amount"))
      if amount<self.__balance:
          self.__amount=amount
          self.__balance=self.__balance-self.__amount
          return f"new balance={self.__balance}"
      else :
          return "insufficient funds"

  def __str__(self):
      return (f"Account number: {Account_no} \nName:{self.__name}\nGender:{self.__gender}\nBalance: {self.__balance}")

  def Transfer(self,acc_number,amount):
      if self.__balance>=amount:
        self.__balance-=amount
        acc_number.__balance+=amount
        if self.__balance<500:
          self.___balance-=500
          return f"balance after deducting fine of 500{self.__balance}"
        return f"transfered amount:{amount} balance:{acc_number.__balance}"
      else:
          return "Insufficient Funds"
      
def menu():
  print("------------------------------------")
  print("BANKING MANGEMENT SYSTEM")
  print("1.CREATE ACCOUNT")
  print("2.DEPOSIT MONEY")
  print("3.WITHDRAW MONEY")
  print("4.TRANSFER MONEY")
  print("5.SHOW BALANCE")
  print("0.EXIT")
 
s={}

while True:
    menu()
    choice=int(input("enter your choice: "))
    if choice==1:
      print("Welcome")
      name=input("enter name: ")
      balance=float(input("enter balance: "))
      gender=input("enter gender: ")
      a=Account(name,balance,gender)
      s[a.Account_no]=a
      #

    if choice==2:
      acno=int(input("enter account number: "))
      a.deposit(acno)

    if choice==3:
      acno=int(input("enter account number: "))
      a.withdraw(acno)
    if choice==4:
      accno1=int(input("enter acno1: "))
      accno2=int(input("enter acno2: "))
      amount=float(input("enter amount: "))
      if accno1 in s and accno2 in s:
        print(s[accno1].Transfer(s[accno2],amount))
      else:
        print("Account number not found")

    if choice==5:
      for Account_no in s:
        print(s[Account_no])
    if choice==0:
      print("Exiting...")
      break
# Out:
# ------------------------------------
# BANKING MANGEMENT SYSTEM
# 1.CREATE ACCOUNT
# 2.DEPOSIT MONEY
# 3.WITHDRAW MONEY
# 4.TRANSFER MONEY
# 5.SHOW BALANCE
# 0.EXIT
# Welcome
# Account created
# Account number:1001
# Account created with accno:1001
# ------------------------------------
# BANKING MANGEMENT SYSTEM
# 1.CREATE ACCOUNT
# 2.DEPOSIT MONEY
# 3.WITHDRAW MONEY
# 4.TRANSFER MONEY
# 5.SHOW BALANCE
# 0.EXIT
# Welcome
# Account created
# Account number:1002
# Account created with accno:1002
# ------------------------------------
# BANKING MANGEMENT SYSTEM
# 1.CREATE ACCOUNT
# 2.DEPOSIT MONEY
# 3.WITHDRAW MONEY
# 4.TRANSFER MONEY
# 5.SHOW BALANCE
# 0.EXIT
# Exiting...
