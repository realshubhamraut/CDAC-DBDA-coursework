# %%
obj=open("amar.txt","w")
line=input("Enter data:")
obj.write(line)
obj.close()
# Out:
# Enter data:efkjn;oadnf;oenf;ian;gnweoignoqwng;weng;owne;ogn

# %%
obj=open("amar2.txt","a")
line=input("Enter data:")
obj.write("\n"+line)
obj.close()
# Out:
# Enter data:3rd line goes here.

# %%
obj=open("amar2.txt","r")

all_data=obj.read()
print(all_data)
obj.close()
# Out:
# this is line 1.Line 2 here.
# 3rd line goes here.

# %%
obj=open("amar2.txt","r")

# %%
all_data=obj.readline()

# %%
print(all_data)

# %%
obj=open("amar2333.txt","r")
while True:
    line=obj.readline()
    if line=="":
        print("---------EOF-----------")
        break
    print(line)
obj.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1543231498.py in <cell line: 0>()
# ----> 1 obj=open("amar2333.txt","r")
#       2 while True:
#       3     line=obj.readline()
#       4     if line=="":
#       5         print("---------EOF-----------")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'amar2333.txt'

# %%
📝 Problem Definition: User Contact File Generator
1. Goal
The primary goal is to develop a program that securely collects Name, Email address, and Contact Number from the user, validates the input for basic correctness, and then permanently stores this data in a structured, readable format within a designated file.

2. Input
The program must prompt the user to input the following three mandatory data fields:

User Name: Full name (or preferred name).

Email Address: A valid email address (e.g., user@example.com).

Contact Number: A numerical string representing a phone number (e.g., 10 digits).

3. Processing and Constraints
The program must perform the following actions and adhere to the specified constraints:

Input Collection: Prompt the user clearly for each of the three data points.

Basic Validation:

Name: Must not be empty.

Email: Must contain the '@' symbol and a '.' (dot) after the '@'.

Number: Must only contain digits and be a reasonable length (e.g., 10 digits for standard mobile numbers).

File Handling: The program must open a specified file (e.g., user_contacts.txt or a dynamically named file) in append mode to ensure existing data is not overwritten.

Data Formatting: The collected and validated data must be formatted into a consistent, easily parsable structure before being written to the file. A suitable format could be a Comma-Separated Values (CSV) style or a label-based block format.

4. Output
The program's output will consist of two main components:

File Output (Persistent Storage): The collected data for each user is written to the output file in a clear, formatted manner.

Example Formats:

CSV: Amar Panchal,amar.career@example.com,9821601163

Block:

--- Contact Record ---
Name: Amar Panchal
Email: amar.career@example.com
Number: 9821601163
----------------------

# %%
#only read things that had error
def validator(name,contact,email):
    error_name=error_number=error_email=False
    if name=="":
        error_name=True

    flag=False
    for i in contact:#ASDFGHJKL1
        if not(i>='0' and i<='9'):
            flag=True
            break
    if len(contact)!=10 or flag==True:#10 units and all numbers only
        error_number=True

    if '@' not in email and '.' not in email:
        error_email=True

    return error_name,error_number,error_email

# %%
#only read things that had error
def validator(name,contact,email):
    flag=False
    for i in contact:#ASDFGHJKL1
        if not(i>='0' and i<='9'):
            flag=True
            break
    if len(contact)!=10 or flag==True:#10 units and all numbers only
        contact=""

    if '@' not in email and '.' not in email:
        email=""

    return name,contact,email


name=input("Enter name:")
contact=input("Enter contact:")
email=input("Enter email:")
while True:

    name,contact,email=validator(name,contact,email)

    if name!="" and contact!="" and email !="":
        break

    else:
        if name=="":
            print("--->Name can not be blank")
            name=input("Enter name:")

        if contact=="":
            print("--->Error in contact re enter")
            contact=input("Enter contact:")

        if email=="":
            print("--->Valid email id needed")
            email=input("Enter email:")



obj=open(name+".txt","a")
obj.write(f"Name: {name}")
obj.write(f"\nContact: {contact}")
obj.write(f"\nEmail: {email}")
obj.close()
# Out:
# Enter name:amar panchal
# Enter contact:9821601163
# Enter email:amar here
# --->Valid email id needed
# Enter email:aa@bb.CC

# %%
log=open("log.txt","w")
name=input("Enter name:")
log.write(name)
contact=input("Enter contact:")
log.write("\n"+contact)
email=input("Enter email:")
log.write("\n"+email)
log.close()
while True:
    log=open("log.txt","r")

    error_name,error_contact,error_email=validator(name,contact,email)

    if not error_name and not error_contact and not error_email:
        break

    else:
        if error_name==True:
            print("--->Name can not be blank")
            name=input("Enter name:")
        else:
            name=


        if error_contact==True:
            print("--->10 digit numbers only needed")
            contact=input("Enter contact:")

        if error_email==True:
            print("--->Valid email id needed")
            email=input("Enter email:")



obj=open(name+".txt","a")
obj.write(f"Name: {name}")
obj.write(f"\nContact: {contact}")
obj.write(f"\nEmail: {email}")
obj.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4190242440.py in <cell line: 0>()
#       1 log=open("log.txt","w")
# ----> 2 name=input("Enter name:")
#       3 log.write(name)
#       4 contact=input("Enter contact:")
#       5 log.write("\n"+contact)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
email="abc@d.com"
if '@' not in email and '.' not in email:
        print("True")
else:
        print("False")
# Out:
# False

# %%
contact='9821AA1163'
error_number=False
flag=False
for i in contact:#ASDFGHJKL1
    if not(i>='0' and i<='9'):
        flag=True
        break
print(len(contact))
if len(contact)!=10 or flag==True:#10 units and all numbers only
    error_number=True
print("Error Raised:",error_number)
# Out:
# 10
# Error Raised: True

# %%
file1.txt
1
2
3
4
5
6
7
8
9
# Out:
# 9

# %%
file2.txt
a
b
c
d
e
f
g
i
j
k
l

# %%
f1=open("file1.txt","r")
f2=open("file2.txt","r")
f3=open("file3.txt","w")
while True :
    line_1=f1.readline()
    f3.write(line_1)
    line_2=f2.readline()
    f3.write(line_2)
    if line_1=="" and line_2=="":
        break

f1.close()
f2.close()
f3.close()
