# %%
 
# 1. Write a program that takes a number as input and prints out whether it is an even or odd 
# number.  
# 2. Write a program that takes a year as input and prints out whether it is a leap year or not.  
# 3. Write a program that takes a string as input and checks whether it is a 
# palindrome or not.  
# 4. Write a program that takes three numbers as input and prints out the largest one. 5. Write a 
# program that takes a sentence as input and counts the number of words in it.  
# 6. Write a pr

# %%
def even_odd(n):
    if n % 2 == 0:
        print("The number is even")
    else:
        print("odd")
    
even_odd(11)
# Out:
# odd

# %%
def leap_year(n):
    if (n % 400 == 0) or (n % 4 == 0 and n % 100!=0):
        print("Leap year")
    else:
        print("not a leap year")

leap_year(2001)
# Out:
# not a leap year

# %%
def leap(n):
    if (n%4==0 and n % 100 !=0) or (n%400 == 0):
        print("leap")
    else:
        print("not leap")
leap(200)
# Out:
# not leap

# %%
# Out:
# Counter({'B': 5, 'A': 3, 'C': 2})

# %%
from colections import defaultdict
data = [('shubh', 24), ('Bob', 90), ('Dim')]
# Out:
# Counter({1: 3, 4: 2, 2: 1, 5: 1})

# %%
from collections import defaultdict

data = [('Alice', 85), ('Bob', 90), ('Alice', 88), ('Bob', 95), ('Charlie', 78)]

grouped_scores = defaultdict(list)
for name, score in data:
    grouped_scores[name].append(score)

print(grouped_scores)
# Out:
# defaultdict(<class 'list'>, {'Alice': [85, 88], 'Bob': [90, 95], 'Charlie': [78]})

# %%
array = [12,11,45,1,6,123]
low = array[0]
for i in array:
    if i < low:
        low = i
print(low)
# Out:
# 1

# %%
# Out:
# 6

# %%
print(int(1011))

print(int('1011',23))

print(int(1011,2))

print(int('1011'))
# Out:
# 1011
# 12191
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 print(int(1011))
#       3 print(int('1011',23))
# ----> 5 print(int(1011,2))
#       7 print(int('1011'))
#
# TypeError: int() can't convert non-string with explicit base
