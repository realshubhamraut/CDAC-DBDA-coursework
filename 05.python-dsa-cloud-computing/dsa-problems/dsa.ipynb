# %%
# %%html
# <link href="https://fonts.googleapis.com/css2?family=Source+Serif+4:wght@300;400;500;600;700&display=swap" rel="stylesheet">
#
# <style>
# /* markdown + output */
# body, .markdown-body, .jp-RenderedHTMLCommon, div.text_cell_render,
# .notebook, .notebook * {
#   font-family: "Source Serif 4", serif !important;
# }
#
# /* code editor (monaco) */
# .monaco-editor, .monaco-editor * {
#   font-family: "Source Serif 4", serif !important;
# }
# </style>
# Out:
# <link href="https://fonts.googleapis.com/css2?family=Source+Serif+4:wght@300;400;500;600;700&display=swap" rel="stylesheet">
#
# <style>
# /* markdown + output */
# body, .markdown-body, .jp-RenderedHTMLCommon, div.text_cell_render,
# .notebook, .notebook * {
#   font-family: "Source Serif 4", serif !important;
# }
#
# /* code editor (monaco) */
# .monaco-editor, .monaco-editor * {
#   font-family: "Source Serif 4", serif !important;
# }
# </style>

# %% [markdown]
# Q1 - 217. Contains Duplicate

# %%
from typing import List

class Solution:
    def containsDuplicate(self, nums: List[int]) -> bool:
        return len(nums) != len(set(nums))
    

nums = [1,2,3,4]
sol = Solution()
print(sol.containsDuplicate(nums))
# Out:
# False

# %% [markdown]
# Q2 - 242. Valid Anagram

# %%
class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        if sorted(s) == sorted(t):
            return True
        else: return False



s = 'shubham'
t = 'bhamshu'

sol = Solution()
print(sol.isAnagram(s,t))
# Out:
# True

# %% [markdown]
# q3 - 1. Two Sum

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        for i in range(len(nums)-1):
            for j in range(i+1, len(nums)):
                if nums[i] + nums[j] == target:
                    return [i,j]
                
nums = [1,2,4,1]
target = 2
sol = Solution()
print(sol.twoSum(nums, target))
# Out:
# [0, 3]

# %% [markdown]
# q4 - 347. Top K Frequent Elements

# %%
class Solution:
    def topKFrequent(self, nums, k):
        from collections import Counter
        count = Counter(nums)
        bucket = [[] for _ in range(len(nums) + 1)]
        for num, freq in count.items():
            bucket[freq].append(num)
        res = []
        for i in range(len(nums), 0, -1):
            for num in bucket[i]:
                res.append(num)
                if len(res) == k:
                    return res
                
nums = [1, 1, 1, 2, 2, 3]
k = 2
sol = Solution()
print(sol.topKFrequent(nums, k))
# Out:
# [1, 2]

# %% [markdown]
# q5 - 49. Grouping anagrams in together from list

# %%
from typing import List
class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        hashmap = {}
        for word in strs:
            sorted_word = ''.join(sorted(word))

            if sorted_word not in hashmap:
                hashmap[sorted_word] = []

            hashmap[sorted_word].append(word)
        return list(hashmap.values())
strs = ["eat", "tea", "tan", "ate", "nat", "bat"]
sol = Solution()
print(sol.groupAnagrams(strs))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %% [markdown]
# 1. create a hashmap / dict
#
# - create an empty dict, will store groups
# - `key` = sorted signature
# - `value` = lists of words that match the signature
#
# ```python
#         hashmap = {}
# ```
# ---
# 2. iterate through each word in from str and sort each char from word and join it back
#
# ```python
#         for word in strs:
#             sorted_word = ''.join(sorted(word))
# ```
# ---
#
# 3.	Insert Into Hashmap
# -	If the signature is not in hashmap → create an empty list.
# -	Append the original word to the corresponding list.
#
# ```python
#         if sorted_word not in hashmap:
#             hashmap[sorted_word] = []
#         hashmap[sorted_word].append(word)
# ```
# ---
# 4. 	The values of the dictionary contain the grouped anagrams.
#
# ```python
#         return list(hashmap.values())
# ```

# %%
class Solution:
    def topKFrequent(self, nums, k):
        # get freq count
        count = {}
        for i in nums:
            if i in count:
                count[i] = count[i] + 1
            else:
                count[i] = 1
        # bucket     
        freq = []
        for i in range(len(nums)+ 1):
            freq.append([])
        
        # put nums in bucket
        for number in count:
            frequency = count[number]
            freq[frequency].append(number)
        
        result = []
        index = len(freq) -1 
        while index > 0:
            for number in freq[index]:
                result.append(number)

                if len(result) == k:
                    return result
            index = index -1
obj = Solution()
nums = [1,2,2,2,1,1,3,4,4,4,4,4,4,5,6,7]
k = 2
output = obj.topKFrequent(nums, k)
print(output)
# Out:
# [4, 1]

# %% [markdown]
# 1. **Create a HashMap to Count Frequencies**
#    - We'll count how many times each number appears.
#    - `key` = number, `value` = frequency of that number.
#    ```python
#    count = {}
# ---
#
# 2.	Fill the Frequency Map
# 	-	Loop through each number in nums.
# 	-	If seen before → increase count.
# 	-	If not → initialize with 1.
#
#    ```python
#         for i in nums:
#             if i in count:
#                 count[i] = count[i] + 1
#             else:
#                 count[i] = 1
#    ```
# ---
#
# 3.	Create a List of Buckets
#    -	Index of each bucket = frequency.
#    -	Each bucket holds numbers that appear that many times.
#    -	We need len(nums) + 1 buckets because a number could appear up to len(nums) times.
# ```python
#         freq = []
#         for i in range(len(nums)+ 1):
#             freq.append([])
# ```
#
# ---
#
# 4. **Collect the Top K Frequent Numbers**
#    - Start from the bucket with the highest frequency (rightmost index).
#    - Move downward toward lower frequencies.
#    - Each bucket may contain one or more numbers.
#    - Keep adding numbers to the result until we have `k` of them.
#
# ```python
#          result = []
#          index = len(freq) - 1          # start at highest frequency
#          while index > 0:
#             for number in freq[index]:  # check all numbers with this frequency
#                result.append(number)
#                if len(result) == k:    # stop once we've taken k elements
#                      return result
#             index = index - 1           # move to the next lower frequency
# ```

# %%
class Solution:
    def topkFrequen(self, nums, k):
        freq = {}
        for x in nums:
            if x in freq:
                freq[x] = freq[x] + 1
            else:
                freq[x] = 1
        return freq

# %%
class Solution():
    def topkfreqElements(self, nums, k):
        freq = {}
        
        # count frequencies
        for i in nums:
            if i in freq:
                freq[i] += 1
            else:
                freq[i] = 1
        
        # sort by frequency (value), descending
        dict_freq = dict(sorted(freq.items(), key=lambda item: item[1], reverse=True))
        
        result = []
        count = 0
        
        for key, value in dict_freq.items():
            if count < k:
                result.append(key)
                count += 1
            else:
                break
        
        return result


nums = [1,1,2,1,2,1,22,222,22,2,222,2,2,2,2,2,2,4]
k = 2

sol = Solution()
output = sol.topkfreqElements(nums, k)
print(output)
# Out:
# [2, 1]
